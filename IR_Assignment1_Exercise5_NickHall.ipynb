# %%
import numpy as np
import matplotlib.pyplot as plt

recall_1 = [0, 0, 0, 0.25, 0.5, 0.5, 0.5, 0.75, 0.75, 1]
precision_1 = [0, 0, 0, 0.25, 0.40, 0.33, 0.29, 0.38, 0.33, 0.40]

recall_2 = [0.25, 0.25, 0.25, 0.5, 0.5, 0.75, 0.75, 0.75, 1, 1]
precision_2 = [1, 0.5, 0.33, 0.5, 0.4, 0.5, 0.43, 0.38, 0.44, 0.4]

fig, ax = plt.subplots()

ax.set(xlabel='Recall', ylabel='Precision')
plt.plot(recall_1, precision_1)
plt.plot(recall_2, precision_2)


plt.legend(loc='lower right')
ax.legend(['First line', 'Second line'])
# Out:
# WARNING:matplotlib.legend:No handles with labels found to put in legend.
